# %% [markdown]
# https://consultaremedios.com.br/dimesilato-de-lisdexanfetamina/bula#:~:text=Dimesilato%20de%20Lisdexanfetamina%20%C3%A9%20indicado%20como%20parte%20integrante%20de%20um,os%20pacientes%20com%20este%20transtorno.

# %%
import pandas as pd

# Dados para Transtornos Psiquiátricos
tp_data = {
    "Reação adversa": ["Insônia", "Agitação", "Ansiedade", "Logorreia", "Diminuição da libido", 
                       "Depressão", "Tique", "Labilidade emocional", "Disforia", "Euforia",
                       "Hiperatividade psicomotora", "Bruxismo", "Dermatilomania", 
                       "Episódios psicóticos", "Mania", "Alucinação", "Agressão"],
    "TDAH - Adultos": ["Muito comum", "Muito comum", "Comum", "Incomum", "Comum", 
                       "Incomum", "Incomum", "Comum", "Incomum", "Incomum", 
                       "Comum", "Comum", "Incomum", "Incidência não conhecida", 
                       "Incomum*", "Incidência não conhecida", "Incidência não conhecida"],
    "TDAH - Adolescentes": ["Muito comum", "Muito comum", "Comum", "Incomum", 
                            "Incidência não conhecida", "Comum", "Incomum", 
                            "Incomum", "Incomum", "Incomum", "Incomum", 
                            "Incomum", "Incomum", "Incidência não conhecida", 
                            "Incomum*", "Incomum", "Incomum"],
    "TDAH - Crianças": ["Muito comum", "Muito comum", "Incomum", "Incomum", 
                        "Não aplicável", "Incomum", "Comum", "Incomum", 
                        "Incomum", "Incidência não conhecida", "Incomum", 
                        "Incomum*", "Incomum*", "Incidência não conhecida", 
                        "Incomum*", "Incomum", "Comum"],
    "TCA - Adultos": ["Muito comum", "Incomum", "Comum", "Incomum", "Comum", 
                      "Incomum", "Incomum", "Comum", "Incomum", "Incidência não conhecida", 
                      "Comum", "Comum", "Incomum", "Incidência não conhecida", "Incomum*", 
                      "Incomum*", "Incidência não conhecida"]
}

# Convertendo para dataframe
tp_df = pd.DataFrame(tp_data)

# Dados para Distúrbios do Sistema Nervoso
dsn_data = {
    "Reação adversa": ["Dor de cabeça", "Tontura", "Inquietação", "Tremor", 
                       "Sonolência", "Convulsão", "Discinesia", "Disgeusia"],
    "TDAH - Adultos": ["Muito comum", "Comum", "Comum", "Comum", "Incomum", 
                       "Incidência não conhecida", "Incomum*", "Incomum"],
    "TDAH - Adolescentes": ["Muito comum", "Comum", "Comum", "Comum", 
                            "Comum", "Incidência não conhecida", "Incomum", 
                            "Incomum"],
    "TDAH - Crianças": ["Muito comum", "Comum", "Incomum", "Incomum*", 
                        "Comum", "Incidência não conhecida", "Incomum*", 
                        "Incomum"],
    "TCA - Adultos": ["Muito comum", "Comum", "Incomum", "Comum", 
                      "Incomum", "Incidência não conhecida", "Incomum", 
                      "Comum"]
}

# Convertendo para dataframe
dsn_df = pd.DataFrame(dsn_data)

# Dados para Distúrbios Visuais
dv_data = {
    "Reação adversa": ["Visão turva", "Midríase", "Diplopia"],
    "TDAH - Adultos": ["Incomum", "Incidência não conhecida", "Incidência não conhecida"],
    "TDAH - Adolescentes": ["Incidência não conhecida", "Incomum*", "Incidência não conhecida"],
    "TDAH - Crianças": ["Incomum", "Incomum", "Incidência não conhecida"],
    "TCA - Adultos": ["Incomum", "Incidência não conhecida", "Incidência não conhecida"]
}

# Convertendo para dataframe
dv_df = pd.DataFrame(dv_data)

# Dados para Distúrbios Cardíacos
dc_data = {
    "Reação adversa": ["Taquicardia", "Palpitação", "Cardiomiopatia"],
    "TDAH - Adultos": ["Comum", "Comum", "Incidência não conhecida"],
    "TDAH - Adolescentes": ["Comum", "Comum", "Incomum*"],
    "TDAH - Crianças": ["Comum", "Incomum", "Incidência não conhecida"],
    "TCA - Adultos": ["Comum", "Comum", "Incidência não conhecida"]
}

# Convertendo para dataframe
dc_df = pd.DataFrame(dc_data)

# Análise descritiva estatística dos dataframes
print("Transtornos Psiquiátricos:")
display(tp_df)
print(tp_df.describe())
print("\nDistúrbios do Sistema Nervoso:")
display(dsn_df)
print(dsn_df.describe())
print("\nDistúrbios Visuais:")
display(dv_df)
print(dv_df.describe())

print("\nDistúrbios Cardíacos:")
display(dc_df)
print(dc_df.describe())
# Out:
# Transtornos Psiquiátricos:
#                 Reação adversa            TDAH - Adultos  \
# 0                      Insônia               Muito comum
# 1                     Agitação               Muito comum
# 2                    Ansiedade                     Comum
# 3                    Logorreia                   Incomum
# 4         Diminuição da libido                     Comum
# 5                    Depressão                   Incomum
# 6                        Tique                   Incomum
# 7         Labilidade emocional                     Comum
# 8                     Disforia                   Incomum
# 9                      Euforia                   Incomum
# 10  Hiperatividade psicomotora                     Comum
# 11                    Bruxismo                     Comum
# 12              Dermatilomania                   Incomum
# 13        Episódios psicóticos  Incidência não conhecida
# 14                       Mania                  Incomum*
# ...
